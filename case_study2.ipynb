# %%
import numpy as np # data arrays
import pandas as pd # data structure and data analysis
import matplotlib as plt # data visualization
import datetime as dt # date time

import os
for dirname, _, filenames in os.walk('kaggle kernels output shaanjain/ballbeat-case-study-google-capstone-project -p /path/to/dest'):
    for filename in filenames:
        print(os.path.join(dirname,filename))

# %%
df1 = pd.read_csv('C:/Users/paris/Desktop/Data_Analysis/Case_Study_2/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# obtain the # of missing data points per column
missing_values_count = df1.isnull().sum()

# look at the # of missing points in all columns
missing_values_count[:]
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df1.duplicated().any()
# Out:
# False

# %%
df1.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
#df1.drop_duplicates("Id")
#df1_count = (df1.drop_duplicates("Id")).count
#df1_count
unique_id = len(pd.unique(df1["Id"]))
print("# of unique Id:" +str(unique_id))
# Out:
# # of unique Id:33

# %%
pd.pivot_table(df1,
              index = 'Id',
              values = 'ActivityDate',
              aggfunc = ['count'],
              margins = True,
              margins_name = 'Total Count')
# Out:
#                    count
#             ActivityDate
# Id
# 1503960366            31
# 1624580081            31
# 1644430081            30
# 1844505072            31
# 1927972279            31
# 2022484408            31
# 2026352035            31
# 2320127002            31
# 2347167796            18
# 2873212765            31
# 3372868164            20
# 3977333714            30
# 4020332650            31
# 4057192912             4
# 4319703577            31
# 4388161847            31
# 4445114986            31
# 4558609924            31
# 4702921684            31
# 5553957443            31
# 5577150313            30
# 6117666160            28
# 6290855005            29
# 6775888955            26
# 6962181067            31
# 7007744171            26
# 7086361926            31
# 8053475328            31
# 8253242879            19
# 8378563200            31
# 8583815059            31
# 8792009665            29
# 8877689391            31
# Total Count          940

# %%
df1.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df1["ActivityDate"]
# Out:
# 0     2016-04-12
# 1     2016-04-13
# 2     2016-04-14
# 3     2016-04-15
# 4     2016-04-16
#          ...
# 935   2016-05-08
# 936   2016-05-09
# 937   2016-05-10
# 938   2016-05-11
# 939   2016-05-12
# Name: ActivityDate, Length: 940, dtype: datetime64[ns]

# %%
# convert "ActivityDate" to datatime64 dtype and format to yyyy-mm-dd
df1["ActivityDate"] = pd.to_datetime(df1["ActivityDate"], format="%m/%d/%Y")

# re-print information to confirm
df1.info()

# print the first 5 rows of "ActivityDate" to confirm
df1["ActivityDate"].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    datetime64[ns]
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
new_col=['Id', 'ActivityDate','DayOfTheWeek', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
       'LoggedActivitiesDistance', 'VeryActiveDistance',
       'ModeratelyActiveDistance', 'LightActiveDistance',
       'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
       'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

df1_1=df1.reindex(columns=new_col)
df1_1

df1_1["DayOfTheWeek"]= df1_1["ActivityDate"].dt.day_name()
df1_1["DayOfTheWeek"].head(9)
# Out:
# 0      Tuesday
# 1    Wednesday
# 2     Thursday
# 3       Friday
# 4     Saturday
# 5       Sunday
# 6       Monday
# 7      Tuesday
# 8    Wednesday
# Name: DayOfTheWeek, dtype: object

# %%
try1=df1_1[["DayOfTheWeek","SedentaryMinutes"]].sort_values(by='DayOfTheWeek')
print(try1.groupby('DayOfTheWeek').sum())
# Out:
#               SedentaryMinutes
# DayOfTheWeek
# Friday                  126039
# Monday                  123353
# Saturday                119571
# Sunday                  119821
# Thursday                141413
# Tuesday                 153119
# Wednesday               148422

# %%
pd.pivot_table(df1_1,
              index = 'DayOfTheWeek',
              values = ['SedentaryMinutes'],
              aggfunc = ['count'],
              margins = True,
              margins_name = 'Total Count')
# Out:
#              count
#                 Id SedentaryMinutes
# DayOfTheWeek
# Friday         126              126
# Monday         120              120
# Saturday       124              124
# Sunday         121              121
# Thursday       147              147
# Tuesday        152              152
# Wednesday      150              150
# Total Count    940              940

# %%
df1_1["TotalHour"]=(df1_1["VeryActiveMinutes"]+df1_1["LightlyActiveMinutes"]+df1_1["SedentaryMinutes"])/60

# %%
df1_1["TotalHour"].head(9)
# Out:
# 0    18.016667
# 1    16.900000
# 2    23.816667
# 3    16.066667
# 4    17.166667
# 5    12.350000
# 6    23.733333
# 7    18.150000
# 8    17.516667
# Name: TotalHour, dtype: float64

# %%
import matplotlib.pyplot as plt

# plotting histogram
plt.style.use("default")
plt.figure(figsize=(6,4)) # specify size of the chart
plt.hist(df1_1.DayOfTheWeek, bins = 7, 
         width = 0.6, color = "lightskyblue", edgecolor = "black")
# Out:
# (array([152., 150., 147., 126., 124., 121., 120.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <a list of 7 Patch objects>)

# %%
# import matplotlib package
import matplotlib.pyplot as plt

# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) # specify size of the chart
plt.scatter(df1_1.TotalSteps, df1_1.Calories, 
            alpha = 0.8, c = df1_1.Calories, 
            cmap = "Spectral")
# add annotations and visuals
median_calories = 2303
median_steps = 7637
plt.colorbar(orientation = "vertical")
plt.axvline(median_steps, color = "Blue", label = "Median steps")
plt.axhline(median_calories, color = "Red", label = "Median calories burned")
plt.xlabel("Steps taken")
plt.ylabel("Calories burned")
plt.title("Calories burned for every step taken")
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(8,6)) # Specify size of the chart
plt.scatter(df1_1.TotalHour, df1_1.Calories, 
            alpha = 0.8, c = df1_1.Calories, 
            cmap = "Spectral")
# adding annotations and visuals
median_calories = 2303
median_hours = 20
median_sedentary = 991 / 60

plt.colorbar(orientation = "vertical")
plt.axvline(median_hours, color = "Blue", label = "Median steps")
plt.axvline(median_sedentary, color = "Purple", label = "Median sedentary")
plt.axhline(median_calories, color = "Red", label = "Median hours")
plt.xlabel("Hours logged")
plt.ylabel("Calories burned")
plt.title("Calories burned for every hour logged")
plt.legend()
plt.grid(True)
plt.show()

# %%
# calculating total of individual minutes column
very_active_mins = df1_1["VeryActiveMinutes"].sum()
fairly_active_mins = df1_1["FairlyActiveMinutes"].sum()
lightly_active_mins = df1_1["LightlyActiveMinutes"].sum()
sedentary_mins = df1_1["SedentaryMinutes"].sum()

# plotting pie chart
slices = [very_active_mins, fairly_active_mins, lightly_active_mins, sedentary_mins]
labels = ["Very active minutes", "Fairly active minutes", "Lightly active minutes", "Sedentary minutes"]
colours = ["lightcoral", "yellowgreen", "lightskyblue", "darkorange"]
explode = [0, 0, 0, 0.1]
plt.style.use("default")
plt.pie(slices, labels = labels, 
        colors = colours, wedgeprops = {"edgecolor": "black"}, 
        explode = explode, autopct = "%1.1f%%")
plt.title("Percentage of Activity in Minutes")
plt.tight_layout()
plt.show()
